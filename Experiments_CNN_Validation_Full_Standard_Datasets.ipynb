# %% [markdown]
# ### **Mount G-Drive to Colab**

# %% [markdown]
# Only run below when on colab, otherwise you can ignore (pip installing the packages may however be useful if environment hasn't yet been set up)

# %%
# ### Mount google drive to Colab VM
# from google.colab import drive
# drive.mount('/content/drive')

# # folder name where scripts will be ...
# FOLDERNAME = '' # <- relative path to QGCN repository

# # Now that we've mounted your Drive, this ensures that
# # the Python interpreter of the Colab VM can load
# # python files from within it.
# import sys
# import os
# fullPath = '/content/drive/MyDrive/{}'.format(FOLDERNAME)
# sys.path.append(fullPath)

# # drive.mount("/content/drive", force_remount=True)
# print("Printing Directory Contents for confirmation")
# os.chdir(fullPath)
# print(os.path.abspath("."))
# current_file_dirpath = os.path.dirname(os.path.realpath('__file__'))
# print(current_file_dirpath)
# !ls

# !pip install wget torch-geometric torch-cluster torch-sparse torch-scatter

# %% [markdown]
# ### Main Command lines To Run

# %%
# !python3 ./generate_rawgraph_data.py --dataset=MNIST # Generates the geometric dataset for MNIST image dataset

# %%
# !python3 ./generate_rawgraph_data.py --dataset=FashionMNIST # Generates the geometric dataset for FashionMNIST image dataset

# %%
# !python3 ./generate_rawgraph_data.py --dataset=CIFAR10 # Generates the geometric dataset for CIFAR10 image dataset

# %%
# !python3 ./run_experiments_cnn_full_standard_datasets.py --dataset=standard --notraineval --profilemodels # Only run to get profiling stats on the model(s)

# %%
# !python3 ./run_experiments_cnn_full_standard_datasets.py --dataset=standard --notraineval
